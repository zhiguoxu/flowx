# %%
from core.rag.document_loaders.loader import AutoFileLoader

loader = AutoFileLoader(file_path="./files/RM51.pdf")

# %%
loader.load()

# %%
from core.rag.document_loaders.dir_loader import DirLoader

dir_loader = DirLoader(file_or_dir="./files")

# %%
dir_loader.load()

# %%
import nest_asyncio
nest_asyncio.apply()

from core.rag.document_loaders.web import WebLoader

loader = WebLoader("https://lilianweng.github.io/posts/2023-06-23-agent/")
loader.load()
